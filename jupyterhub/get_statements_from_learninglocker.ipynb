# %%
import json
import requests
import socket
 

url = 'http://{}/api/v1/statements/where'.format(socket.gethostbyname('learning_locker'))
user = "f0c7c001d095a9d901faeadecdcb9c2cc00fb5ef"
passwd = "aaba53816dd23f63b93e9a79e81db55059d2c310"

params = 'filters=[["statement.timestamp", "between", "2013-01-01", "2019-01-15"]]'
r = requests.get(url, auth=(user, passwd), params=params)

# Convert JSON to dict
response_data = json.loads(r.text)
 
print(response_data)
# Out:
# {'total': 10, 'per_page': 100, 'current_page': 1, 'last_page': 1, 'from': 1, 'to': 10, 'data': [{'lrs': {'_id': {'$id': '5c88dfdc0e3a2d24008b4567'}}, 'lrs_id': '5c88dfdc0e3a2d24008b4567', 'client_id': '5c88dfdc0e3a2d24008b4568', 'statement': {'version': '1.0.0', 'actor': {'objectType': 'Agent', 'name': '', 'account': {'name': '22', 'homePage': 'http://localhost:8000'}}, 'verb': {'id': 'urn:x-moodle-event-action:submitted', 'display': {'en': 'submitted'}}, 'context': {'contextActivities': {'category': [{'objectType': 'Activity', 'id': 'http://moodle.org', 'definition': {'type': 'http://id.tincanapi.com/activitytype/source', 'name': {'en': 'Moodle'}, 'description': {'en': 'Moodle is a open source learning platform designed to provide educators, administrators and learners with a single robust, secure and integrated system to create personalized learning environments.'}}}], 'grouping': [{'objectType': 'Activity', 'id': 'http://localhost:8000/course/view.php?id=6', 'definition': {'type':
# ...
